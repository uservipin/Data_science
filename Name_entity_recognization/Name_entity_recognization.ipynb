# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/amankharwal/Website-data/master/ner_dataset.csv'

# %%
data = pd.read_csv(url,encoding= 'unicode_escape')

# %%
data
# Out:
#           Sentence #           Word  POS Tag
# 0        Sentence: 1      Thousands  NNS   O
# 1                NaN             of   IN   O
# 2                NaN  demonstrators  NNS   O
# 3                NaN           have  VBP   O
# 4                NaN        marched  VBN   O
# ...              ...            ...  ...  ..
# 1048570          NaN           they  PRP   O
# 1048571          NaN      responded  VBD   O
# 1048572          NaN             to   TO   O
# 1048573          NaN            the   DT   O
# 1048574          NaN         attack   NN   O
#
# [1048575 rows x 4 columns]

# %%
from itertools import chain

def get_dict_map(data,token_or_tag):
    tok2idx = {}
    idx2tok= {}
    
    if token_or_tag == 'token':
        vocab = list(set(data['Word'].to_list()))
    
    else :
        vocab = list(set(data['Tag'].to_list()))
        
    idx2tox = {idx: tok for idx, tok in enumerate(vocab)}
    tok2dx = {tok: idx for idx, tok in enumerate(vocab)}
    print(idx2tox)
    print(tok2dx)
    return tok2dx, idx2tox

# %%
token2idx,idx2token = get_dict_map(data,'token')
# Out:
# {0: '12-kilometer-high', 1: 'Gupta', 2: 'complaint', 3: 'Klammer', 4: 'Izvestia', 5: '31st', 6: 'amass', 7: 'Endeavor', 8: 'CIA-backed', 9: 'pits', 10: 'surrendered', 11: 'Sucumbios', 12: 'attributes', 13: 'Oil-rich', 14: 'Falu', 15: 'DAX', 16: 'rabbis', 17: 'Malacca', 18: 'Akihiko', 19: 'Compensation', 20: 'Extended', 21: 'stoked', 22: '120-seat', 23: 'bureau', 24: 'financially', 25: 'chances', 26: 'Slovenians', 27: 'mutilated', 28: 'Feb-45', 29: 'discomfort', 30: 'revisit', 31: 'starving', 32: 'Hermogenes', 33: 'Gaza-Egypt', 34: 'enrollment', 35: 'pick', 36: 'post-war', 37: 'Sapporo', 38: 'Tekunan', 39: 'Shootings', 40: 'manganese', 41: 'denials', 42: 'chronic', 43: 'Al-Mukmin', 44: 'Aliu', 45: 'FRG', 46: 'Juarez', 47: 'poverty-stricken', 48: 'pillars', 49: 'Dong-young', 50: 'dimension', 51: 'shopping', 52: 'backyard', 53: 'miillion', 54: 'Alarcon', 55: 'Del', 56: 'addicts', 57: 'Drapchi', 58: 'deny', 59: 'pro-Western', 60: 'Lions', 61: 'pass', 62: 'delegates', 63: 'los', 64: 'Nations-coordinated', 65: 'statistics', 66: 'pirate', 67: 'banner', 68: 'aspire', 69: 'timelines', 70: 'Complicated', 71: 'Michoacan', 72: 'student', 73: 'shores', 74: 'daylight', 75: 'spleen', 76: 'Bragg', 77: 'wallowing', 78: 'plume', 79: 'Reduction', 80: 'U.N.-African', 81: 'Oprah', 82: 'Azimi', 83: 'Summers', 84: 'disapproved', 85: 'IDB', 86: 'Norte', 87: 'bauxite', 88: 'Melbourne', 89: 'Jabril', 90: 'Previous', 91: 'Yemeni', 92: 'yellow-shirts', 93: 'illustrate', 94: 'Al-Qaida-linked', 95: 'Stronger', 96: '640', 97: 'scattered', 98: 'Ahnlund', 99: 'Act', 100: 'Republic', 101: 'Anwarul', 102: 'recognizes', 103: 'we', 104: 'SEIN', 105: 'conga', 106: 'enclave-type', 107: 'postponement', 108: 'swells', 109: 'tie', 110: 'autonomous', 111: 'Indonesia-Malaysia', 112: 'Whole', 113: 'Helena', 114: 'clarity', 115: 'producer', 116: '1899', 117: 'dial', 118: 'nominating', 119: 'scratched', 120: '69.54', 121: 'tendered', 122: 'Asia-Oceania', 123: 'Talim', 124: 'Vani', 125: 'abbreviations', 126: 'Opec', 127: 'earthquake-triggered', 128: 'Stoffel', 129: 'counter-narcotics', 130: 'goal', 131: 'Silva', 132: 'Dina', 133: 'Subsequent', 134: 'Liaoning', 135: 'launching', 136: 'Christmas', 137: 'Schorr', 138: 'rekindled', 139: 'AOL', 140: 'plundered', 141: 'Vejjajiva', 142: 'Iyad', 143: 'malfunctioned', 144: 'Antilles', 145: 'deposits', 146: 'Big', 147: 'nova', 148: 'lighter', 149: 'bottlenecks', 150: 'cluster', 151: 'Ange-Felix', 152: 'list', 153: 'misfortune', 154: 'Der', 155: 'abstain', 156: 'unsaturated', 157: 'flocking', 158: 'XDR-TB', 159: 'Director', 160: 'cruised', 161: 'estates', 162: 'Allah', 163: 'embarrass', 164: 'Ox', 165: 'SHACKLETON', 166: '18-year-old', 167: 'concession', 168: 'web', 169: 'Inspired', 170: 'splattered', 171: '1278', 172: 'massing', 173: 'briefing', 174: 'Actor', 175: 'pre-marked', 176: 'emanate', 177: 'Yasukuni', 178: 'fractured', 179: 'wipe', 180: 'Nina-Maria', 181: 'substation', 182: 'crow', 183: 'boyfriend', 184: 'reformists', 185: 'transatlantic', 186: 'Tahar', 187: 'Unlike', 188: 'galleries', 189: 'Bank-funded', 190: 'Geologists', 191: 'investors', 192: 'posing', 193: 'revealed', 194: 'Sunni-backed', 195: 'ultimatum', 196: 'Yogi', 197: 'Kariye', 198: 'J.S.', 199: 'near-simultaneous', 200: 'Jammu-Kashmir', 201: '20-meter', 202: 'reburied', 203: 'assailants', 204: 'two-dozen', 205: 'Uribana', 206: 'unprotected', 207: 'Zaid', 208: '38.875', 209: 'operator', 210: 'ducks', 211: 'Beruit', 212: 'anti-genetic', 213: 'Mar-46', 214: 'Wei', 215: 'MICHEL', 216: '65th', 217: 'Annexation', 218: 'buoys', 219: 'Troop', 220: 'Players', 221: 'goods', 222: 'Two-time', 223: 'Hector', 224: 'Forty-seven', 225: 'bomb', 226: '62', 227: 'drawn-out', 228: 'First-half', 229: 'Supporters', 230: 'cinema', 231: 'Jalani', 232: 'Rose', 233: '20,00,000', 234: 'cubic', 235: 'MAS', 236: 'Trevor', 237: 'Yinghua', 238: 'drug-running', 239: 'lap', 240: 'manipulating', 241: 'Broncos', 242: 'imagine', 243: 'soprano', 244: 'completing', 245: 'Afghanistan', 246: 'TOR-M1',  ...
# %%
data['Word_idx'] = data['Word'].map(token2idx)
data['Tag_idx'] =data['Tag'].map(tag2idx)

# %%
data_fillna = data.fillna(method= 'ffill', axis= 0)

# %%
data_group = data_fillna.groupby(
    ['Sentence #'], as_index= False
)['Word','POS','Tag','Word_idx','Tag_idx'].agg(lambda X : list(x))
# Out:
# C:\Users\Ai\AppData\Local\Temp/ipykernel_10560/2570540761.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data_group = data_fillna.groupby(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10560/2570540761.py in <module>
# ----> 1 data_group = data_fillna.groupby(
#       2     ['Sentence #'], as_index= False
#       3 )['Word','POS','Tag','Word_idx','Tag_idx'].agg(lambda X : list(x))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1008                 gba = GroupByApply(self, [func], args=(), kwargs={})
#    1009                 try:
# -> 1010                     result = gba.agg()
#    1011
#    1012                 except ValueError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in agg(self)
#     162         elif is_list_like(arg):
#     163             # we require a list, but not a 'str'
# --> 164             return self.agg_list_like()
#     165
#     166         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in agg_list_like(self)
#     353                 colg = obj._gotitem(col, ndim=1, subset=selected_obj.iloc[:, index])
#     354                 try:
# --> 355                     new_res = colg.aggregate(arg)
#     356                 except (TypeError, DataError):
#     357                     pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     247             # but not the class list / tuple itself.
#     248             func = maybe_mangle_lambdas(func)
# --> 249             ret = self._aggregate_multiple_funcs(func)
#     250             if relabeling:
#     251                 # error: Incompatible types in assignment (expression has type
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_multiple_funcs(self, arg)
#     301
#     302             key = base.OutputKey(label=name, position=idx)
# --> 303             results[key] = self.aggregate(func)
#     304
#     305         if any(isinstance(x, DataFrame) for x in results.values()):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     263
#     264             try:
# --> 265                 return self._python_agg_general(func, *args, **kwargs)
#     266             except KeyError:
#     267                 # TODO: KeyError is raised in _python_agg_general,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#    1330             try:
#    1331                 # if this function is invalid for this dtype, we will ignore it.
# -> 1332                 result = self.grouper.agg_series(obj, f)
#    1333             except TypeError:
#    1334                 warnings.warn(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func, preserve_dtype)
#    1047
#    1048         else:
# -> 1049             result = self._aggregate_series_fast(obj, func)
#    1050
#    1051         npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_fast(self, obj, func)
#    1072         ids = ids.take(indexer)
#    1073         sgrouper = libreduction.SeriesGrouper(obj, func, ids, ngroups)
# -> 1074         result, _ = sgrouper.get_result()
#    1075         return result
#    1076
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\reduction.pyx in pandas._libs.reduction._BaseGrouper._apply_to_group()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#    1316     def _python_agg_general(self, func, *args, **kwargs):
#    1317         func = com.is_builtin_func(func)
# -> 1318         f = lambda x: func(x, *args, **kwargs)
#    1319
#    1320         # iterate through "columns" ex exclusions to populate output dict
#
# ~\AppData\Local\Temp/ipykernel_10560/2570540761.py in <lambda>(X)
#       1 data_group = data_fillna.groupby(
#       2     ['Sentence #'], as_index= False
# ----> 3 )['Word','POS','Tag','Word_idx','Tag_idx'].agg(lambda X : list(x))
#
# NameError: name 'x' is not defined
